# %% [markdown]
# # Markdowns
# ## Markdowns
# ### Markdowns
# #### Markdowns

# %% [markdown]
# [site](https://www.gitam.edu/)

# %% [markdown]
# ![text](https://images.pexels.com/photos/358457/pexels-photo-358457.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500)

# %% [markdown]
# #creating ordered list
# 1. abs
# 2. hsdf
#   1. a
#   2. b

# %% [markdown]
# unordered list:
# - abd
# - jhj
#   - jh
#   -jh

# %% [markdown]
# ## bold and italic
# **GITAM**
#
# *GITAM*

# %%
#Basic hello
print("Hello world!!")
# Out:
# Hello world!!

# %%
# Variable creation
x = 10
y = 20
x + y
# Out:
# 30

# %% [markdown]
# # Rules for variable
# - name should begin with a character
# - no special character allowed except_

# %%
name ="Priya"
age  =19
print("my name is:",name,"age is:",age)
# Out:
# my name is: Priya age is: 19

# %%
name = input("enter name")
age = int(input("enter age"))
print("my name is:",name,"age is:",age)
# Out:
# enter nameajay
# enter age20
# my name is: ajay age is: 20

# %%
x = 5
y = 6
x+y
# Out:
# 11

# %%
x-y
# Out:
# -1

# %%
x*y
# Out:
# 30

# %%
x/y
# Out:
# 0.8333333333333334

# %%
x = int(input("enter value of x"))
y = int(input("enter value of y"))
x+y,x-y,x*y,x/y,x%y
# Out:
# enter value of x4
# enter value of y5
# (9, -1, 20, 0.8, 4)

# %% [markdown]
# # fundamental datatypes
# - int
# - float
# - complex
# - boolean
# - string

# %%
x = 10
y = 12.32
z = 5+6j
print(type(x))
print(type(y)) 
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
c = complex(2,5)
print(c)
# Out:
# (2+5j)

# %%
c1 = 2+4j
c2 = 6+5j
c1+c2,c1-c2,c1*c2
# Out:
# ((8+9j), (-4-1j), (-8+34j))

# %%
a = True
b = False
a < b
# Out:
# False

# %%
x = 6
y = 9
x < y
# Out:
# True

# %%
# string 
s1 = "abd"
s2 = "dfg"
print(type(s1),type(s2))
# Out:
# <class 'str'> <class 'str'>

# %%
i = 100
print(type(i))
s1 = str(i)
print(type(s1))
f1=float(i)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
# length
a = str(1234)
print(len(a))
# Out:
# 4

# %%
n1 = 100 #single variable assignment
a = b = c =20 #multiple variable assignment 
a1,b1,c1=123,234,345
print(n1)
print(a,b,c)
print(a1,b1,c1)
# Out:
# 100
# 20 20 20
# 123 234 345

# %% [markdown]
# # Precedence of the arth operation
# - parenthesis
# - power
# - multiplication
# - addition

# %%
x = 1 + 2 ** 3/4 + 5 
print(x)
# Out:
# 8.0

# %%
x = 1 + 2 ** 3/4 * 5
print(x)
# Out:
# 11.0

# %% [markdown]
# # Operators
# ## Arithmetic Operators
# - +
# - -
# - *
# - /
# - %
# - **
# - //

# %%
x = 2
y = 3
x ** y,x // y
# Out:
# (8, 0)

# %% [markdown]
# # Relational operators
#  ==,!=,<,>,<=,>=

# %%
x = 5
a = x > 10
print(a)
# Out:
# False

# %% [markdown]
# # logical operator
# - and
# - or
# - not

# %%
a = 100 
a1 = (i > 15) and (i > 76)
a2 = (i > 56) and (i > 3456)
print(a1)
print(a2)
print(not i)
# Out:
# True
# False
# False

# %% [markdown]
# # Membership operator
# - in
# - not in

# %%
str1 = "abc"
print('a' in str1)
print('a' not in str1)
# Out:
# True
# False

# %% [markdown]
# # control flow statements
# - Conditional statements
# - Looping statements
# - -if-else statement
#   - syntax
#   ##### if condition:
#   > statements<br>
#   ##### else:
#   > statements

# %%
# check whether the given is even or odd
n = int(input("enter a number"))
if n%2 ==0:
  print("even")
else:
    print("odd")
# Out:
# enter a number5
# odd

# %%
# check whether the number is perfectly multiple of 3 and 5
n = int(input("enter a number"))
if(n%3 == 0 & n%5 ==0):
  print("yes")
else:
    print("no")
# Out:
# enter a number15
# yes

# %%
 # check given number is positive,negative or zero
  n = int(input("enter a number"))
 if n>0
   print("positive")
   elif n<0:
     print("negative")
   else:
     print("zero")
# Out:
#   File "<ipython-input-59-1e1b74aef022>", line 2
#     if n = int(input)
#     ^
# IndentationError: unexpected indent
